# %% [markdown]
# # Scraping the data

# %%
import pandas as pd

# %% [markdown]
# https://data.cdp.net/resource/cp8q-9kwm.json\

# %%
df = pd.read_csv('https://data.cdp.net/resource/cp8q-9kwm.csv')

# %%
df[['country','scope_2_metric_tonnes_co2e']].boxplot(by='country',figsize=(25,10));

# %%
grpCountry = df.groupby('Country')['scope_2_metric_tonnes_co2e'].mean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-d4cd1a010bb0> in <module>()
# ----> 1 grpCountry = df.groupby('Country')['scope_2_metric_tonnes_co2e'].mean
#
# ~\AppData\Local\ESRI\conda\envs\datavis\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\AppData\Local\ESRI\conda\envs\datavis\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
# ...
